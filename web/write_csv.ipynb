# %%
import pandas as pd

# %%
db = pd.read_csv('db_pecem.csv')
db.head()
# Out:
#                          image_name  \
# 0    Cam 321 - 21.10.2022 - 22h.jpg
# 1  Cam - 321 - 23.10-2022 - 02h.jpg
# 2  Cam - 321 - 22.10.2022 - 08h.jpg
# 3  Cam - 321 - 22.10.2022 - 10h.jpg
# 4  Cam - 321 - 22.10.2022 - 12h.jpg
#
#                                           image_path  cam_num  shift  \
# 0  ./dataset_pecem_merged/cam_321/Cam 321 - 21.10...  cam_321  noite
# 1  ./dataset_pecem_merged/cam_321/Cam - 321 - 23....  cam_321  noite
# 2  ./dataset_pecem_merged/cam_321/Cam - 321 - 22....  cam_321    dia
# 3  ./dataset_pecem_merged/cam_321/Cam - 321 - 22....  cam_321    dia
# 4  ./dataset_pecem_merged/cam_321/Cam - 321 - 22....  cam_321    dia
#
#                                    ref_excelente  \
# 0  /dataset_pecem/cam_321/Excelente/Imagem28.jpg
# 1  /dataset_pecem/cam_321/Excelente/Imagem28.jpg
# 2  /dataset_pecem/cam_321/Excelente/Imagem27.jpg
# 3  /dataset_pecem/cam_321/Excelente/Imagem27.jpg
# 4  /dataset_pecem/cam_321/Excelente/Imagem27.jpg
#
# ...

# %%
image_name = 'Cam 321 - 21.10.2022 - 22h.jpg'
ev_id = '0001'

confirma_buttom = True

# %%
pred_label = 'Ruim'

if confirma_buttom:
    ev_label = pred_label
elif b1:
    ev_label = 'Excelente'
elif b2:
    ev_label = 'Bom'
elif b3:
    ev_label = 'Ruim'
elif b4:
    ev_label = 'Pessimo'
    
db.loc[db['image_name']==image_name, 'pred_label'] = pred_label
if ev_id == '0001':
    db.loc[db['image_name']==image_name, 'ev_label_1'] = ev_label
elif ev_id == '0002':
    db.loc[db['image_name']==image_name, 'ev_label_2'] = ev_label
elif ev_id == '0003':
    db.loc[db['image_name']==image_name, 'ev_label_3'] = ev_label
elif ev_id == '0004':
    db.loc[db['image_name']==image_name, 'ev_label_4'] = ev_label
elif ev_id == '0005':
    db.loc[db['image_name']==image_name, 'ev_label_5'] = ev_label
db.to_csv('db_pecem.csv',index=False)

# %%
db.head()
# Out:
#                          image_name  \
# 0    Cam 321 - 21.10.2022 - 22h.jpg
# 1  Cam - 321 - 23.10-2022 - 02h.jpg
# 2  Cam - 321 - 22.10.2022 - 08h.jpg
# 3  Cam - 321 - 22.10.2022 - 10h.jpg
# 4  Cam - 321 - 22.10.2022 - 12h.jpg
#
#                                           image_path  cam_num  shift  \
# 0  ./dataset_pecem_merged/cam_321/Cam 321 - 21.10...  cam_321  noite
# 1  ./dataset_pecem_merged/cam_321/Cam - 321 - 23....  cam_321  noite
# 2  ./dataset_pecem_merged/cam_321/Cam - 321 - 22....  cam_321    dia
# 3  ./dataset_pecem_merged/cam_321/Cam - 321 - 22....  cam_321    dia
# 4  ./dataset_pecem_merged/cam_321/Cam - 321 - 22....  cam_321    dia
#
#                                    ref_excelente  \
# 0  /dataset_pecem/cam_321/Excelente/Imagem28.jpg
# 1  /dataset_pecem/cam_321/Excelente/Imagem28.jpg
# 2  /dataset_pecem/cam_321/Excelente/Imagem27.jpg
# 3  /dataset_pecem/cam_321/Excelente/Imagem27.jpg
# 4  /dataset_pecem/cam_321/Excelente/Imagem27.jpg
#
# ...
