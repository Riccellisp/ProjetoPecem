# %%
import pandas as pd
from PIL import Image
from matplotlib import pyplot as plt

# %%
db = pd.read_csv('db_pecem.csv')
db.head()
# Out:
#                          image_name  \
# 0    Cam 321 - 21.10.2022 - 22h.jpg
# 1  Cam - 321 - 23.10-2022 - 02h.jpg
# 2  Cam - 321 - 22.10.2022 - 08h.jpg
# 3  Cam - 321 - 22.10.2022 - 10h.jpg
# 4  Cam - 321 - 22.10.2022 - 12h.jpg
#
#                                           image_path  cam_num  shift  \
# 0  ./dataset_pecem_merged/cam_321/Cam 321 - 21.10...  cam_321  noite
# 1  ./dataset_pecem_merged/cam_321/Cam - 321 - 23....  cam_321  noite
# 2  ./dataset_pecem_merged/cam_321/Cam - 321 - 22....  cam_321    dia
# 3  ./dataset_pecem_merged/cam_321/Cam - 321 - 22....  cam_321    dia
# 4  ./dataset_pecem_merged/cam_321/Cam - 321 - 22....  cam_321    dia
#
#                                    ref_excelente  \
# 0  /dataset_pecem/cam_321/Excelente/Imagem28.jpg
# 1  /dataset_pecem/cam_321/Excelente/Imagem28.jpg
# 2  /dataset_pecem/cam_321/Excelente/Imagem27.jpg
# 3  /dataset_pecem/cam_321/Excelente/Imagem27.jpg
# 4  /dataset_pecem/cam_321/Excelente/Imagem27.jpg
#
# ...

# %%
ev_id = '0002'

# %%
if ev_id == '0001':
    ev_0001_to_ev = db[db['ev_label_1'].isnull()]
    for path in ev_0001_to_ev['image_path']:
        print(path)
        img = Image.open(path)
        plt.imshow(img)
        plt.show()
        #predict(image)
        #write_csv...
# Out:
# ./dataset_pecem_merged/cam_321/Cam - 321 - 23.10-2022 - 02h.jpg
# ./dataset_pecem_merged/cam_321/Cam - 321 - 22.10.2022 - 08h.jpg
# ./dataset_pecem_merged/cam_321/Cam - 321 - 22.10.2022 - 10h.jpg
# ./dataset_pecem_merged/cam_321/Cam - 321 - 22.10.2022 - 12h.jpg
# ./dataset_pecem_merged/cam_321/Cam - 321 - 22.10.2022 - 14h.jpg
# ./dataset_pecem_merged/cam_321/Cam - 321 - 25.10.2022 - 12h.jpg
# ./dataset_pecem_merged/cam_321/Cam 321 - 21.10.2022 - 12h.jpg
# ./dataset_pecem_merged/cam_321/Cam - 321 - 24.10.2022 - 22h.jpg
# ./dataset_pecem_merged/cam_321/Cam - 321 - 25.10.2022 - 04h.jpg
# ./dataset_pecem_merged/cam_321/Cam - 321 - 22.10.2022 - 20h.jpg
# ./dataset_pecem_merged/cam_321/Cam - 321 - 22.10.2022 - 00h.jpg
# ./dataset_pecem_merged/cam_321/Cam - 321 - 23.10-2022 - 14h.jpg
# ./dataset_pecem_merged/cam_321/Cam - 321 - 22.10.2022 - 18h.jpg
# ./dataset_pecem_merged/cam_321/Cam - 321 - 23.10-2022 - 18h.jpg
# ./dataset_pecem_merged/cam_321/Cam - 321 - 25.10.2022 - 00h.jpg
# ...
